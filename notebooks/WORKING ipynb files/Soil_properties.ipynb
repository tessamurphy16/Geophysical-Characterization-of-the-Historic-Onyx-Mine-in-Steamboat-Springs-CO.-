# %%
import geopandas as gpd

soil = gpd.read_file("../../data/soil/CO648/spatial/soilmu_a_co648.shp")
print(soil.crs)
soil.head()
# Out:
# EPSG:4326
#   AREASYMBOL  SPATIALVER MUSYM   MUKEY  \
# 0      CO648           8   10C  506858
# 1      CO648           8    7E  506854
# 2      CO648           8   165  506990
# 3      CO648           8   50E  506891
# 4      CO648           8   27A  506866
#
#                                             geometry
# 0  POLYGON ((-107.22785 40.59521, -107.22745 40.5...
# 1  POLYGON ((-107.30828 40.58803, -107.30804 40.5...
# 2  POLYGON ((-107.07113 40.56723, -107.07073 40.5...
# 3  POLYGON ((-106.92289 40.56669, -106.92257 40.5...
# 4  POLYGON ((-106.99693 40.55978, -106.99688 40.5...

# %%
soil.plot(figsize=(10,8))
# Out:
# <Axes: >
